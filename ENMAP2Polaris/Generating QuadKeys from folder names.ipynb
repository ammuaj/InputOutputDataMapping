# %% [markdown]
# # Generating Quadkeys for each state

# %%
import os
import pickle

# %%
path = '/s/lovelace/e/nobackup/sangmi/amatin/PhD_Research_Works/KD_TS_Works/data/resampled_data/CA_z13_for_TS_model/gridmet_data'

folder = path

sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]

#print(sub_folders)
print(f"total sub folders {len(sub_folders)}")

#sub folder named after each quadkey
allQuadKeys = sub_folders
# Out:
# total sub folders 193

# %%
allQuadKeys
# Out:
# ['0230103002013',
#  '0230102010302',
#  '0230130220133',
#  '0230100221011',
#  '0230102131313',
#  '0230133002202',
#  '0230103002200',
#  '0230100200000',
#  '0230102012300',
#  '0230123111003',
#  '0230133201030',
#  '0230132001320',
#  '0230101232333',
#  '0230103020033',
#  '0230103223123',
#  '0230103000130',
#  '0230100223130',
#  '0230100012102',
#  '0230101232332',
#  '0230120113101',
#  '0230100223131',
#  '0230100312033',
#  '0230102001320',
#  '0230100232222',
#  '0230120103010',
#  '0230103322102',
#  '0230101230203',
#  '0230103011310',
#  '0230100222200',
#  '0230103121001',
#  '0230120110123',
#  '0230100101032',
#  '0230102113133',
#  '0230132010021',
#  '0230100221101',
#  '0230131220213',
#  '0230100223103',
#  '0230102010300',
#  '0230121112022',
#  '0230130132332',
#  '0230102331120',
#  '0230100221001',
#  '0230102001131',
#  '0230100221112',
#  '0230101221003',
#  '0230102121311',
#  '0230100221320',
#  '0230102213333',
#  '0230132003211',
#  '0230102010031',
# ...

# %%
# Saving the quadkeys for each state (SMAP data)
save = True
if save: 
    with open('CA_station_area_quadKey_z13_list.pkl', 'wb') as fp:
        pickle.dump(allQuadKeys, fp)
